# %%
# !pip install sentence_transformers
# !pip install transformers
# !pip install git+https://github.com/huggingface/transformers

# %%
# pip install torch

# %%
#pip install textblob

# %%
# pip install pyspellchecker
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for pyspellchecker from https://files.pythonhosted.org/packages/e1/d2/c7e3b3a61a34b9320399fa731d1f9f0c73db8a1f28c6764e9e11efa68a29/pyspellchecker-0.8.1-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/6.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.8 MB 991.0 kB/s eta 0:00:07
#    - -------------------------------------- 0.2/6.8 MB 2.1 MB/s eta 0:00:04
#    -- ------------------------------------- 0.4/6.8 MB 3.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.0/6.8 MB 5.5 MB/s eta 0:00:02
#    ------------ --------------------------- 2.1/6.8 MB 9.1 MB/s eta 0:00:01
#    ------------------------ --------------- 4.2/6.8 MB 15.6 MB/s eta 0:00:01
#    ------------------------------ --------- 5.2/6.8 MB 16.0 MB/s eta 0:00:01
#    ---------------------------------------  6.8/6.8 MB 18.8 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import nltk
import re
from nltk.corpus import stopwords#, PlainTextCorpusReader
from nltk import word_tokenize, ngrams
from nltk.stem import WordNetLemmatizer
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import seaborn as sns
import torch
from transformers import LlamaTokenizer
from sentence_transformers import SentenceTransformer
import warnings
warnings.filterwarnings('ignore')
# from textblob import TextBlob
from spellchecker import SpellChecker

# %%
path = "../00_Data/"
filename = 'text.csv'
raw_data = pd.read_csv(path+filename)
raw_data.tail()
# Out:
#         Unnamed: 0                                               text  label
# 416804      416804  i feel like telling these horny devils to find...      2
# 416805      416805  i began to realize that when i was feeling agi...      3
# 416806      416806  i feel very curious be why previous early dawn...      5
# 416807      416807  i feel that becuase of the tyranical nature of...      3
# 416808      416808  i think that after i had spent some time inves...      5

# %% [raw]
# Each entry in this dataset consists of a text segment representing a Twitter message and a corresponding label indicating the predominant emotion conveyed. The emotions are classified into six categories:
# sadness (0),
# joy (1),
# love (2),
# anger (3),
# fear (4),
# surprise (5). Whether you're interested in sentiment analysis, emotion classification, or text mining, this dataset provides a rich foundation for exploring the nuanced emotional landscape within the realm of social media.

# %%
class_to_emotion = {0: 'sadness', 1: 'joy', 2: 'love', 3: 'anger', 4: 'fear', 5: 'surprise'}
raw_data['emotion'] = raw_data['label'].map(class_to_emotion)
# 
category_counts = raw_data['emotion'].value_counts()

# %%
raw_data
# Out:
#         Unnamed: 0                                               text  label  \
# 0                0      i just feel really helpless and heavy hearted      4
# 1                1  ive enjoyed being able to slouch about relax a...      0
# 2                2  i gave up my internship with the dmrg and am f...      4
# 3                3                         i dont know i feel so lost      0
# 4                4  i am a kindergarten teacher and i am thoroughl...      4
# ...            ...                                                ...    ...
# 416804      416804  i feel like telling these horny devils to find...      2
# 416805      416805  i began to realize that when i was feeling agi...      3
# 416806      416806  i feel very curious be why previous early dawn...      5
# 416807      416807  i feel that becuase of the tyranical nature of...      3
# 416808      416808  i think that after i had spent some time inves...      5
#
#          emotion
# 0           fear
# ...

# %%
plt.figure(figsize=(8, 6))
#category_counts.plot(kind='bar')#, color='skyblue')  # Create the bar plot
plt.title('Bar Plot of Emotion Counts')
sns.countplot(data=raw_data, x='emotion', palette='hsv') 
plt.xlabel('Emotions')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [raw]
# It looks like we have an imbalanced dataset. Therefore, we may consider further processing data to balance the dataset. First we process everything without balancing data and later we can balance the dataset to improve the performance of our baseline model if needed.

# %%
raw_data.head()
# Out:
#    Unnamed: 0                                               text  label  \
# 0           0      i just feel really helpless and heavy hearted      4
# 1           1  ive enjoyed being able to slouch about relax a...      0
# 2           2  i gave up my internship with the dmrg and am f...      4
# 3           3                         i dont know i feel so lost      0
# 4           4  i am a kindergarten teacher and i am thoroughl...      4
#
#    emotion
# 0     fear
# 1  sadness
# 2     fear
# 3  sadness
# 4     fear

# %%
raw_data.shape
# Out:
# (416809, 4)

# %%
data=raw_data[['text', 'label']]
del raw_data

# %%
data.groupby('label').count()
# Out:
#          text
# label
# 0      121187
# 1      141067
# 2       34554
# 3       57317
# 4       47712
# 5       14972

# %%
data['text'] = data['text'].astype(str)
data['text'] = data['text'].str.lower()
data['text'] = data['text'].str.replace('[^\w\s]','') #  ^\w looks for all words (a to z, 0-9 including _) \S is any character that is NOT a whitespace character

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\mahsh\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
wordnet_lemmatizer = WordNetLemmatizer()
stop = stopwords.words('english')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mahsh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mahsh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\mahsh\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
print(stop)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
# The "'" is removed in the words e.g. 'ive' instead of 'i've
#intentinally did not include 'ill'
more_stopwords = ['im', 'isnt', 'arent', 'aint', 'dont', 'doesnt', 'would', 'wont', 'werent', 'wasnt', \
                 'couldnt', 'shouldnt', 'wouldnt', 'mightnt','cant', 'shant', 'hasnt', 'havent', 'neednt', \
                 'mustnt', 'ive', 'weve', 'shes', 'hes', 'shed', 'id', 'hed', 'theyve', 'theyd', 'wed', \
                 'couldve', 'wouldve', 'shouldve', 'mustve'] 
stop += more_stopwords
print(stop)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
# Make a dictionary of abbreviations common in twitter
# Ref: https://www.socialmediatoday.com/content/top-twitter-abbreviations-you-need-know 
# also added some manually
abbreviations = {
    "ab": "about",
    "abt": "about",
    "afaik": "as far as i know",
    "ayfkmwts": "are you fucking kidding me with this shit",
    "b4": "before",
    "bfn": "bye for now",
    "bgd": "background",
    "bh": "blockhead",
    "br": "best regards",
    "btw": "by the way",
    "cd9": "code 9, parents are around",
    "chk": "check",
    "csl": "can't stop laughing",
    "cu": "see you",
    "cya": "see you",
    "cul8r": "see you later",
    'cx':'correction',
    "dam": "don’t annoy me",
    "dd": "dear daughter",
    "df": "dear fiancé",
    'dm':'direct message',
    "dp": "profile pic",
    "ds": "dear son",
    "dyk": "did you know",
    "em": "email",
    "eml": "email",
    "ema": "email address",
    'expo':'exposition',
    "f2f": "face to face",
    "ftf": "face to face",
    "fb": "facebook",
    "ff": "follow friday",
    "ffs": "for fuck's sake",
    "fml": "fuck my life.",
    "fotd": "find of the day",
    "ftw": "for the win, fuck the world",
    "fubar": "fucked up beyond all repair",
    "fwiw": "for what it's worth.",
    "gal": "get a life",
    "gg": "good game",
    "gmafb": "give me a fucking break",
    "gtfooh": "get the fuck out of here",
    "gts": "guess the song",
    "hagn": "have a good night",
    "hand": "have a nice day",
    "hotd": "headline of the day",
    "ht": "heard through",
    "hth": "hope that helps",
    "ic": "i see",
    "icymi": "in case you missed it",
    "idc": "i don't care",
    "idk": "i don't know",
    "iirc": "if i remember correctly",
    "imho": "in my humble opinion",
    "irl": "in real life",
    "iwsn": "i want sex now",
    "jk": "just kidding",
    "jsyk": "just so you know",
    "jv": "joint venture",
    "kk": "ok",
    "kyso": "knock your socks off",
    "lhh": "laugh hella hard",
    "lmao": "laughing my ass off",
    "lmfao": "laughing my fucking ass off",
    "lmk": "let me know",
    "lo": "little one",
    "lol": "laugh out loud",
    "mm": "music monday",
    "mirl": "meet in real life",
    "mrjn": "marijuana",
    "nbd": "no big deal",
    "nct": "nobody cares, though",
    "nfw": "no fucking way",
    "njoy": "enjoy",
    "nsfw": "not safe for work",
    "nts": "note to self",
    "oh": "overheard",
    "omfg": "oh my fucking god",
    'omg':'oh my god',
    "oomf": "one of my friends",
    "orly": "oh, really?",
    "plmk": "please let me know",
    "pnp": "party and play",
    "qotd": "quote of the day",
    'r':'are',
    "re": "in reply to",
    "rlrt": "real-life re-tweet, a close cousin to oh",
    "rtfm": "read the fucking manual",
    "rtq": "read the question",
    "sfw": "safe for work",
    "smdh": "shaking my damn head",
    "smh": "shaking my head",
    "snafu": "situation normal all fucked up",
    "sob": "son of a bitch",
    "srs": "serious",
    "stfu": "shut the fuck up",
    "stfw": "search the fucking web",
    "tftf": "thanks for the follow",
    "tftt": "thanks for this tweet",
    "thx": "thanks",
    "tj": "tweetjack",
    "tl": "timeline",
    "tldr": "too long, didn’t read",
    "tmb": "tweet me back",
    "tt": "trending topic",
    "ty": "thank you",
    "tyia": "thank you in advance",
    "tyt": "take your time",
    "tyvw": "thank you very much",
    "u": "you",
    'uni':'university',
    "ur": "your",
    "u2": "you too",
    "w": "with",
    "we": "weekend",
    "wtv": "whatever",
    'wud':'would',
    "ygtr": "you got that right",
    "ykwim": "you know what i mean",
    "ykyat": "you know you're addicted to",
    "ymmv": "your mileage may vary",
    "yolo": "you only live once",
    "yoyo": "you're on your own",
    "yw": "you're welcome",
    "zomg": "omg to the max",
    "zzz": "sleeping, bored"
}
# misspelling = {'becuase':'because'} # found by acient in the data
# repl_dictionary = {**abbreviations, **misspelling}

# %%
nrows=len(data)
clean = []
for row in range (0,nrows):
    text = data.loc[row]['text']
    text = re.sub(r'https?://[^\s\n\r]+', '', text) #remove hyperlink (anything after https)
    text = re.sub(r'#', '', text) # remove "#" from word
    text = re.sub(r'^RT[\s]+', '', text) # remove "RT" (old-style retweet)
    text_words = text.split(" ")
    clean_row = []
    for word in text_words:
        # replace abbreviations
        if word in abbreviations.keys():
            word = abbreviations[word]
        clean_row.append(word)  
    clean.append(" ".join(clean_row))
data['text_WO_abbr'] = clean
data.head()
# Out:
#                                                 text  label  \
# 0      i just feel really helpless and heavy hearted      4
# 1  ive enjoyed being able to slouch about relax a...      0
# 2  i gave up my internship with the dmrg and am f...      4
# 3                         i dont know i feel so lost      0
# 4  i am a kindergarten teacher and i am thoroughl...      4
#
#                                         text_WO_abbr
# 0      i just feel really helpless and heavy hearted
# 1  ive enjoyed being able to slouch about relax a...
# 2  i gave up my internship with the dmrg and am f...
# 3                         i dont know i feel so lost
# 4  i am a kindergarten teacher and i am thoroughl...

# %% [markdown]
# TextBlob library corrects misspellings based on the entire sentence context, rather than word by word. It considers the context of each word in the sentence to suggest corrections. This approach is generally more effective in NLP but it took a while to run. Therefore, we used "spellchecker" insteda which check spelling word by word.
# Since it is word by word we are applying it after removing stopwords

# %%
# # Takes long to run

# # Define a function to correct misspellings using TextBlob
# def correct_spelling(text):
#     blob = TextBlob(text)
#     corrected_text = blob.correct()
#     return str(corrected_text)

# # Apply the function to the 'text' column
# data['text_corrected'] = data['text'].apply(correct_spelling)

# %%
def remove_stopwords(text):
    # Tokenize the text into words
    words = nltk.word_tokenize(text)
    filtered_words = [word for word in words if word.lower() not in stop]
    filtered_text = ' '.join(filtered_words)
    
    return filtered_text
data['text_WO_stopwords'] = data['text_WO_abbr'].apply(remove_stopwords)
data.head()
# Out:
#                                                 text  label  \
# 0      i just feel really helpless and heavy hearted      4
# 1  ive enjoyed being able to slouch about relax a...      0
# 2  i gave up my internship with the dmrg and am f...      4
# 3                         i dont know i feel so lost      0
# 4  i am a kindergarten teacher and i am thoroughl...      4
#
#                                         text_WO_abbr  \
# 0      i just feel really helpless and heavy hearted
# 1  ive enjoyed being able to slouch about relax a...
# 2  i gave up my internship with the dmrg and am f...
# 3                         i dont know i feel so lost
# 4  i am a kindergarten teacher and i am thoroughl...
#
#                                    text_WO_stopwords
# 0                 feel really helpless heavy hearted
# 1  enjoyed able slouch relax unwind frankly neede...
# 2            gave internship dmrg feeling distraught
# 3                                     know feel lost
# ...

# %% [markdown]
# From ChatGPT:
# If your NLP task requires precise analysis of the text, such as sentiment analysis, topic modeling, or named entity recognition, it might be beneficial to correct misspellings. Misspellings can introduce noise and reduce the accuracy of your analysis.
# Correcting misspellings can be computationally expensive, especially for large datasets or real-time applications.

# %%
# This cell takes long time to run

# Initialize the spellchecker
spell = SpellChecker()

# Define a function to correct misspellings using pyspellchecker
def correct_spelling(text):
    corrected_words = []
    for word in text.split():
        corrected_word = spell.correction(word)
        if corrected_word is not None:
            corrected_words.append(corrected_word)
        else:
            corrected_words.append(word)  # Keep original word if it cannot be corrected
            print(word) # printing uncorrected words
    corrected_text = ' '.join(corrected_words)
    return corrected_text

# Apply the function to the 'text' column
print('These words cannot be correted:')
data['text_corrected'] = data['text_WO_stopwords'].apply(correct_spelling)
# Out:
# These words cannot be correted:
# pagetitle
# lauterbach
# jonathan
# burlington
# lookaround
# hoyhenkeijukainen
# ezekiel
# atnelsonnest
# october
# thumbelina
# olympian
# verdadero
# jumbleupon
# underappreciated
# logomanaical
# maastricht
# mybangladiary
# nickwilford
# sucksseptember
# easyjet
# joachim
# february
# constantfunk
# haobulicai
# jumprope
# penyakit
# heinlein
# honolulu
# glasgow
# materfamiliasknits
# recordkeeping
# noisescape
# michaelangelos
# donatellos
# sauvignon
# pagetitle
# justmejuliejulie
# ladyfriend
# rantaboutthisandraveaboutthat
# serbidoras
# barcelona
# frontenac
# thismorning
# weinstein
# spicekitchenandbar
# alissakelly
# peoplepress
# european
# blablabla
# sometimeswhy
# wednesdays
# pharmacalogically
# jaejoong
# marybeth
# kentucky
# nababaliw
# kakaisip
# hitomi
# livejournal
# vintagevixon
# ladygarfunkel
# hgttg
# beeyatch
# preworkout
# lactosefreeproteinpowder
# oklahoma
# saturdays
# saturdays
# saturdays
# compostables
# ...

# %%
data.to_csv(path+'temp.csv', header=True)

# %%
# manually correcting some of the above words; when making the corrections stopwords are removed
repl_dictionary = {'pagetitle':'page title', 'lookaround':'look around', 'jumbleupon':'jumble upon',\
                  'sucksseptember':'sucks september', 'constantfunk':'constant funk', 'jumprope':'jump rope',\
                  'recordkeeping':'record keeping', 'noisescape':'noise escape', 'justmejuliejulie':'julie julie',\
                  'ladyfriend':'lady friend', 'rantaboutthisandraveaboutthat':'rant rave', 'thismorning':'morning',\
                  'spicekitchenandbar':'spice kitchen bar', 'blablabla':'blah blah blah', 'sometimeswhy':'sometimes why',\
                  'livejurnal':'live journal', 'beeyatch':'bitch', 'lactosefreeproteinpowder':'lactose free protein powder',\
                  'mommyhood':'motherhood', 'thepopularpodcast':'popular podcast', 'familyscholars':'family scholars',\
                  'soooooo':'so', 'soooooooooooo':'so', 'anotherdamnslblog':'another damn sl blog', 'cuttlebug':'cuttle bug',\
                  'tinyrose':'tiny rose', 'axelrod':'axel rod', 'dogshit':'dog shit', 'whoooole':'whole',\
                  'stuckbetween':'stuck', 'addthis':'add', 'addthisurl':'add url', 'dearwendy':'dear wendy',\
                  'naaaaah':'no', 'hehehe':'laughing', 'petalsandfingers':'petals fingers', 'dresswithpurpose':'dress purpose',\
                  'ourpregnancyproblem':'pregnancy problem', 'reallyyyyy':'really', 'fooooood':'food', 'peejamma':'peejamas',\
                  'importantant':'important', 'viceversa':'vice versa', 'metadescription':'meta description', \
                  'pagetype':'page type', 'ifeeldelicious':'feel delicious', 'reallllyyyyy':'really', \
                   'lemosandeverythingnice':'lemons everything nice', 'dietcoke':'diet coke', 'dancefloor':'dance floor',\
                  'africamusiclaw':'africa music law', 'fairweather':'fair weather', 'hahahaha':'laughing', \
                  'thiscrazymessylife':'crazy messy life', 'kettlebells':'kettle bells', 'freeideasblog':'free ideas blog',\
                  'stopyourdivorceinweeks':'stop divorce weeks', 'popstardust':'popstar dust', 'tracycakes':'tracy cakes',\
                  'prooooooooceeeeeeesss':'process', 'beauracracy':'bureaucracy', 'thesalad':'salad', 'sooooooooooooo':'so',\
                  'feelmyself':'feel', 'supportcrew':'support crew', 'recentlycompleted':'recently completed', \
                  'positionrate':'position rate', 'internaccessory':'intern accessory','cutscenes':'cut scene', 'frameborder':'frame border', \
                  'marginheight':'margin height', 'marginwidth':'margin width', 'moveabletype':'moveable type', \
                  'getyourprettyon':'get pretty', 'yourdailysportsnews':'daily sports news', 'greenlight':'green light',\
                  'llloooonnnnggg':'long', 'fangirl':'fan girl', 'ihaverun':'run', 'designmom':'design mom', 'whhhyyy':'why',\
                   'ourprojectmakeababy':'project make baby', 'singinglesson':'singing lesson', 'verrrrrrrryyyy':'very',\
                   'groundstrength':'ground strength', 'morerepulsive':'more repulsive', 'stumbleupon':'stumble upon', \
                   'longview':'long view', 'reallllly':'really', 'reallyreallyreally':'really', 'clearboth':'clear both',\
                   'sportsgirl':'sports girl', 'dreamcatcher':'dream catcher', 'houseguest':'house guest', 'looooong':'long',\
                   'hadworried':'worried', 'sleeeppppy':'sleepy', 'spellcast':'spell cast', 'nightyyyy':'nighty', \
                   'soooooo':'so', 'lillehammer':'little hammer', 'commentbox':'comment box', 'meatfactory':'meat factory',\
                   'depositfiles':'deposit files', 'mysteriousperceptions':'mysterious perceptions', 'notnotnot':'',\
                   'fashionshow':'fashion show', 'mobileclass':'mobile class', 'languagedirection':'language direction',\
                   'togetherbox':'togetehr box', 'viciouscycle':'vicious cycle', 'babybrother':'baby brother', \
                   'skinnyisasixletetrword':'skinny six letter word', 'hahahah':'laughing', 'iloveme':'love', 'userinfo':'user info',\
                   'openmindded':'openminded', 'everybookeverwritten':'every book ever written', 'articleauthority':'article authority',\
                   'undercontrol':'control', 'isprivateblog':'private blog', 'crazyawsome':'crazy awsome', 'planetwaves':'planet waves',\
                   'adultwork':'adult work', 'wishlist':'wish list', 'energyyyy':'energy', 'freerepublic':'free republic', \
                   'idreamculture':'dream culture', 'perimenopause':'premenopause', 'newwindow':'new window', \
                   'thewritersexperiment':'writers experiment', 'christmastime':'christmas time', 'allowfullscreen':'allow full screen',\
                   'savingyormarriagebeforeitstarts':'saving marriage starts', 'buuuuuuuuuuuut':'', 'ohhhh':'oh', \
                   'usuallyifeelrelativelyintelligent':'usually feel relatively intelligent', 'homeforbusiness':'home business',\
                   'privelledge':'privellege', 'succcksss':'sucks', 'reeeeeeally':'really', 'mooorrre':'more', 'buuuuuuttt':'',\
                   'oneinmillion':'one million', 'soooooo':'so', 'ismobilerequest':'mobile request', 'livejournals':'live journal',\
                   'runfargirl':'run far girl', 'loooove':'love', 'lifewiththreedogs':'life three dog', 'heeeeeey':'hey', \
                   'sweatercoat':'sweater coat', 'workaround':'work around', 'omgomg':'oh god', 'outthere':'out', \
                   'funnyhumorcomedyblog':'funny humor comedy blog', 'oncecalendar':'once calendar', \
                   'mygiantstrawberry':'giant strawberry', 'bluewater':'blue water', 'sparrowinthesnow':'sparrow snow', \
                   'ohhhh':'oh', 'uuuhhh':'uh', 'waaaaayyyy':'way', 'hmmmmmmmm':'hm', 'hearfeelseetaste':'hear feel see taste',\
                   'samenumber':'same number', 'newcomment':'new comment', 'greenbrush':'green brush', \
                   'readpageimage':'read page image', 'everyfuckingthing':'every fucking thing', 'imageswitch':'image switch', \
                   'surpriiiised':'surprised', 'veeeeeeery':'very', 'juuuuust':'', 'lifekey':'life key', 'reallllllly':'really',\
                   'zzzzzzs':'sleeping bored', 'letthemreadbooks':'let read book', 'reaaallyyyy':'really', \
                   'sleepytime':'sleepy time', 'cryinggggggggg':'crying', 'allowtransparency':'allow transparency', \
                   'lipstickmakeseverythingbetter':'lipstick make everything better', 'computerassignment':'computer assignment', \
                   'ohhhhh':'oh', 'otherdays':'days', 'twitterfeeds':'twitter feeds', 'realllllllllllllly':'really', \
                   'relevant link':'relevant link', 'realbaby':'real baby', 'youonly':'only', 'youpublished':'published',\
                   'overrrrrrrrrrrr':'over', 'thankyou':'thank', 'noooothing':'nothing', 'aaaand':'', 'feeeeel':'feel',\
                   'hmmmmmmm':'hm', 'girrrrrl':'girl', 'sinceiwas':'since', 'aaaaall':'all', 'ifeelcharming':'feel charming',\
                   'yourweightlossmethods':'weight loss methods', 'hahahahahahahahahahahahahahaha':'laughing', \
                   'weeeeird':'weird', 'weareindebtetc':'debt etc', 'aidshomosexulaity':'aid homosexuality', 'squeeeeeeze':'squeeze',\
                   'hahahahaha':'laughing', 'susessfuly':'successfully', 'scaledimagefitwidth':'scaled image fit width', \
                   'moodswings':'mood swing', 'moodswing':'mood swing', 'talktalktalktalk':'talk', 'uhhhh':'uh', \
                   'ever known':'ever known', 'iloveyou':'love', 'myselfwanting':'want', 'perfectfriend':'perfect friend',\
                   'hehehe':'laughing', 'nononononono':'no', 'reeeeeaaalllly':'really', 'soooooooo':'so', \
                   'thisismorepersonal':'more personal', 'aloooooot':'lot', 'wayyyyy':'way', 'craaaaaaack':'crack', \
                   'littlestrongbaby':'little strong baby', 'offfffffff':'', 'slowfeel':'slow feel', 'awwweeessoooooooome':'awesome', \
                   'reeeeeally':'really', 'soooooo':'so', 'ahhhhhhhhhhhhhhhhhhhhhhhh':'ah', 'eventhough':'even though', \
                   'kiiiiiiiiiind':'kind', 'sooooooo':'so', 'ahhhhh':'ah', 'daaaaaamn':'damn', 'ifeelost':'feel lost', \
                   'reaaaaaally':'really', 'verrrrrrrryyyy':'very', 'knoooooow':'know', 'isthisreallife':'real life', \
                   'sooooooooo':'so', 'hehehe':'laughing', 'overrrrr':'over', 'sllloooooowwwwwllllly':'slowly', \
                   'ifeelabitnaughtywiththispost':'feel bit naughty post', 'reallllly':'really', 'buuuuuut':'', \
                   'mysimplehappybeautifullife':'simple happy beautiful life', 'soooooooooooooo':'so', 'rooooar':'roar', \
                   'soooooooo':'so', 'readingggggggggggggg':'reading', 'youuuuuuuuuu':'', 'looooong':'long', 'uuuuup':'', \
                   'litttttttttttle':'little', 'daaaaaaaaaaaaaaarling':'darling', 'reallllly':'really', 'yeahhhhh':'yeah',\
                   'reaaaaally':'really', 'ahhhhhhhhhh':'ah', 'shutttttupppp':'shutup', 'liiiittle':'little', \
                   'wayyyyyy':'way', 'oneeeeeeeeeeeeeeeeee':'one', 'allllllll':'all', 'beeeeef':'beef', 'aaaaaaand':'',\
                   'waaaaaaay':'way', 'veeeeeeeerrrrry':'very', 'heheheehehehehe':'laughing', 'ssssssssooooooooo':'so', \
                   'actualllllly':'actually', 'hahahahahah':'laughing', 'doooooooooom':'doom', 'sweeeeeet':'sweet', \
                   'soooooooooooo':'so', 'goddddddddd':'god', 'annnnnymore':'any more', 'studentsfirst':'students first', \
                   'stoooooooop':'stop', 'beeeeeyond':'beyond', 'freeeeeaky':'freaky', 'aaaaall':'all', \
                   'hmmmmmmmmmmmmmmmmmmmmmmmmmmmmmm':'hm', 'loooonnngg':'long', 'huuuuge':'huge', 'reeeeeeeeally':'really', \
                   'thatshowitsdoneinthisindustry':'show done industry', 'extrememmememely':'extremely', 'sooooooo':'so', \
                   'ooooooorrr':'', 'reeeeeeeally':'really', 'finallllll':'final', 'misssyouallllllll':'miss all', \
                   'awwwwww':'aw', 'eaaaat':'eat', 'realllllyyyy':'really', 'maaaaaaaadddd':'mad', 'screeeeeeammmmmmm':'scream', \
                   'wayyyyy':'way', 'harmlessneighborhoodeccentric':'harmless neighborhood eccentric', \
                   'gooooood':'good', 'hahahahaha':'laughing', 'soooooooo':'so', 'dewwww':'dew', 'nowwwwww':'now', \
                   'littlethingsaboutgod':'little things god', 'imgonnagetthroughthis':'gonna get through', 'whathaveyou':'what', \
                   'yourletters':'letters', 'awwwwww':'aw', 'lolololololol':'laughing', 'sstrrreeeeettttccchhhed':'stretch', \
                   'waaaaayyyy':'way', 'claaaaaaaaaaaaaaaaaassssss':'class', 'buuuuuuuut':'', 'damnnnnnn':'damn', \
                   'firstworldproblems':'first world problem', 'loadssssss':'loads', 'annoyedlibrarian':'annoyed librarian', \
                   'alittlebitofdetail':'little bit detail', 'thesmallhousefamily':'small house family', 'youuuuu':'', \
                   'newlazerhairremoval':'new laser hair removal', 'nooooooooooo':'no', 'secretsssssssssss':'secrets', \
                   'realllllllllyyyyyyyyyyyyyy':'really', 'billionrising':'billion rising', 'whoooooooollllle':'whole', \
                   'unmotivatedddd':'unmotivated', 'feelingggggg':'feeling', 'hahahaha':'laughing', 'soooooo':'so', \
                   'onemomentatatime':'one moment time', 'ahhhh':'ah', 'reeaaalllyy':'really', 'pleeaazz':'please', \
                   'fuckfuckfuckfuckfuck':'fuck', 'smarrrrtttt':'smart', 'butttttttttt':'', 'biiiiiiiiiiit':'bit', \
                   'feelingggggg':'feeling', 'hhahahaha':'laughing', 'hahahaha':'laughing', 'hehehehe':'laughing', \
                   'waaaaaaaay':'way', 'dewwww':'dew', 'ahhhhhhhhh':'ah', 'ewwww':'ew', 'uhhhh':'uh', \
                   'ifeelplayfultoday':'feel playful foday', 'newmominthenewcity':'new mom new city', 'reallllyyy':'really',\
                   'illbesatisfiednottoreadinbetweenthelines':'satisfied read between lines', 'sooooooooooooooo':'so', \
                   'soooooooo':'so', 'verrryyyyyy':'very', 'lottttttttt':'lot', \
                   'obsessivecraftingdisorder':'obsessive crafting disorder', 'reallyreally':'really really',\
                   'likepeopleandbutterflies':'like people butterflies', 'lolllll':'laughing', \
                   'sooooooooooooo':'so', 'ahhhhh':'ah', 'weeeeeeeeeeeeeeeeeeeeeeeeeeeeeee':'', \
                   'faaaaaaaaaaaaaaaaaaaaaaaaaast':'fast', 'dizzzzzzzzzzzzzzzzzzzzzzzzzzzy':'dizzy', 'aaaaaaaall':'all', \
                   'passiveaggressiveabuse':'passive aggressive abuse', 'sleeeeeeeeep':'sleep', 'zzzzzzz':'sleepy tired', \
                   'llloooonnnnggg':'long', 'stoppppppppppp':'stop', 'ughhhhhhhh':'ugh', 'aaaaand':'', \
                   'loooooove':'love', 'awwww':'aw', 'sooooooo':'so', 'sighhhhhhhh':'sigh', \
                   'liiiiiiiiiitttllllllleeee':'little', 'loooooool':'laughing', 'bittttttt':'bit', 'treeeeeeee':'tree', \
                   'realllyyy':'really', 'buuuuutttt':'', 'maaaaaaaadddd':'mad', 'screeeeeeammmmmmm':'scream', \
                   'ohhhhh':'oh', 'ahhhh':'ah', 'thelittlethingswedo':'little things', 'looveorhatee':'love hate',\
                   'loooooooong':'long', 'happpppyyyyyyyyy':'happy', 'happybunnylove':'happy bunny love', \
                   'inthewarmholdofyourlovingmind':'warmhod loving mind', 'reaaaaaaaaaally':'really', 'nooooooo':'no', \
                   'everrrrrrrywhere':'every where', 'soooooooooooo':'so', 'nooooooooooooooo':'no', 'allllllllll':'all', \
                   'lllooonnnngggg':'long', 'dividingmoments':'dividing moments', 'wtfffff':'what fuck', \
                   'siiiiiiiick':'sick','ooommmmggggg':'oh god', 'ehehehe':'laughing', 'whattttt':'what', \
                   'comeeeeee':'come', 'onnnnnnnn':'', 'feeeeel':'feel', 'urrrrrgh':'urgh', 'ssssssssooooooooo':'so', \
                   'butthurt':'butt hurt', 'thinkmotivate':'think motivate', 'weeeeeeeeks':'weeks', 'prrrrrretty':'pretty',\
                   'secondlife':'second life', 'toooooo':'too', 'ahhhhhhhhhhhhh':'ah', 'hahahhaa':'laughing', \
                   'goooddd':'good', 'yepppppp':'yep', 'whoooole':'whole', 'toooooooooooooo':'too', 'ohhhh':'oh', \
                   'loooooooootttttt':'lot', 'daaaaaaamn':'damn', 'ittttt':'', 'ummmmmmmmmmmmmmmmmmmmmmmmmmm':'um', \
                   'sooooooooo':'so', 'soooooooo':'so'                 
                  }

# %%
print("Nnumber of words manually corrected:", len(repl_dictionary.keys()))
# Out:
# Nnumber of words manually corrected: 396

# %%
nrows=len(data)
clean2 = []
for row in range (0,nrows):
    text = data.loc[row]['text_corrected']
    text_words = text.split(" ")
    clean_row = []
    for word in text_words:
        # replace misspelling
        if word in repl_dictionary.keys():
            word = repl_dictionary[word]
        clean_row.append(word)  
    clean2.append(" ".join(clean_row))
data['text_corrected2'] = clean2
data.head()
# Out:
#                                                 text  label  \
# 0      i just feel really helpless and heavy hearted      4
# 1  ive enjoyed being able to slouch about relax a...      0
# 2  i gave up my internship with the dmrg and am f...      4
# 3                         i dont know i feel so lost      0
# 4  i am a kindergarten teacher and i am thoroughl...      4
#
#                                         text_WO_abbr  \
# 0      i just feel really helpless and heavy hearted
# 1  ive enjoyed being able to slouch about relax a...
# 2  i gave up my internship with the dmrg and am f...
# 3                         i dont know i feel so lost
# 4  i am a kindergarten teacher and i am thoroughl...
#
#                                    text_WO_stopwords  \
# 0                 feel really helpless heavy hearted
# 1  enjoyed able slouch relax unwind frankly neede...
# 2            gave internship dmrg feeling distraught
# 3                                     know feel lost
# ...

# %% [markdown]
# Someone writing "whhhyyy" could mean emotions as opposed to "why", not sure if we need to change this word, having said that, we are worried about frequency of the same spelling. As a result, it is changed for now.

# %%
nrows=len(data)

lematized_text_list=[]
for row in range (0,nrows):
    lemmatized_list = []
    text = data.loc[row]['text_corrected2']
    text_words = text.split(" ")
    # Iterate through every word to lemmatize
    for word in text_words:
        lemmatized_list.append(wordnet_lemmatizer.lemmatize(word, pos="v"))
        
    lemmatized_text = " ".join(lemmatized_list)
    
    # Append to the list containing the texts
    lematized_text_list.append(lemmatized_text)
    
data['text_lemmatized'] = lematized_text_list
data.head()
# Out:
#                                                 text  label  \
# 0      i just feel really helpless and heavy hearted      4
# 1  ive enjoyed being able to slouch about relax a...      0
# 2  i gave up my internship with the dmrg and am f...      4
# 3                         i dont know i feel so lost      0
# 4  i am a kindergarten teacher and i am thoroughl...      4
#
#                                         text_WO_abbr  \
# 0      i just feel really helpless and heavy hearted
# 1  ive enjoyed being able to slouch about relax a...
# 2  i gave up my internship with the dmrg and am f...
# 3                         i dont know i feel so lost
# 4  i am a kindergarten teacher and i am thoroughl...
#
#                                    text_WO_stopwords  \
# 0                 feel really helpless heavy hearted
# 1  enjoyed able slouch relax unwind frankly neede...
# 2            gave internship dmrg feeling distraught
# 3                                     know feel lost
# ...

# %%
data.tail()
# Out:
#                                                      text  label  \
# 416804  i feel like telling these horny devils to find...      2
# 416805  i began to realize that when i was feeling agi...      3
# 416806  i feel very curious be why previous early dawn...      5
# 416807  i feel that becuase of the tyranical nature of...      3
# 416808  i think that after i had spent some time inves...      5
#
#                                              text_WO_abbr  \
# 416804  i feel like telling these horny devils to find...
# 416805  i began to realize that when i was feeling agi...
# 416806  i feel very curious be why previous early dawn...
# 416807  i feel that becuase of the tyranical nature of...
# 416808  i think that after i had spent some time inves...
#
#                                         text_WO_stopwords  \
# 416804  feel like telling horny devils find site suite...
# 416805  began realize feeling agitated restless though...
# ...

# %%
data.to_csv(path+'clean_text_final_All.csv', header=True) # saving data with all columns

# saving only relevant columns
data = data[['text', 'label', 'text_lemmatized']].rename(columns={'text_lemmatized':'clean_text'})
data.to_csv(path+'clean_text_final.csv', header=True)
data.head()
# Out:
#                                                 text  label  \
# 0      i just feel really helpless and heavy hearted      4
# 1  ive enjoyed being able to slouch about relax a...      0
# 2  i gave up my internship with the dmrg and am f...      4
# 3                         i dont know i feel so lost      0
# 4  i am a kindergarten teacher and i am thoroughl...      4
#
#                                           clean_text
# 0                 feel really helpless heavy hearted
# 1  enjoy able slouch relax unwind frankly need la...
# 2               give internship darg feel distraught
# 3                                     know feel lose
# 4  kindergarten teacher thoroughly weary job take...

# %% [markdown]
# # WordCloud

# %%
from wordcloud import WordCloud
from nltk import word_tokenize, FreqDist

# %%
#Frequency of words
for i in range(6):
    data0 = data[data['label']==i]['clean_text']
    fdist = FreqDist(data0)
    #WordCloud
    wc = WordCloud(width=800, height=400, max_words=50).generate_from_frequencies(fdist)
    plt.figure(figsize=(12,10))
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.title('Word cloud for '+class_to_emotion[i])
    plt.show()

# %% [markdown]
# # Data Embedding for LLM

# %% [markdown]
# Tried two different pre-trained embedding models with different sizes. The first one is the sentence-transformers/all-mpnet-base-v2 model. The second one is the paraprase-MiniLM-L6-v2 model.
# Mpnet-base-v2 is a 768 dimensional vectors while MiniLM-L6-v2 is a 384 dimensional vectors. AI ran Llama models on both embedding datasets. The Mpnet result were better comparing on accuracy.pnet more likely will result better.

# %%
model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')
device=torch.device('cuda' if torch.cuda.is_available() else "cpu")
print(device)
model.to(device)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# cpu
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 384, 'do_lower_case': False}) with Transformer model: MPNetModel
# ...

# %%
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')#'sentence-transformers/all_mpnet_base_v2')
device=torch.device('cuda' if torch.cuda.is_available() else "cpu")
print(device)
model.to(device)
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.73k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# cpu
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 128, 'do_lower_case': False}) with Transformer model: BertModel
# ...

# %%
max_i=data.shape[0]
print("Data shape is:", max_i)
batch_size=50000
num_batches=int(max_i/batch_size)
iloc_indexes=[x*batch_size for x in range(num_batches+1)]
# Out:
# Data shape is: 416809

# %%
print("The number of batches are", num_batches, '\n', 'The batch size is', batch_size)
# Out:
# The number of batches are 8
#  The batch size is 50000

# %%
# Embedding takes too long_ Ran up to here

# %% [raw]
# import os
# os.makedirs('embeddings')

# %%
encoded_text_df_list=[]
n=len(data)
for i in iloc_indexes:
    if i+batch_size>max_i:
        end_i=max_i
    else:
        end_i=i+batch_size
    text=data.iloc[i:end_i]['clean_text'].values
    embeddings = model.encode(text)
    embedded_df = pd.DataFrame(embeddings)
    embedded_df.columns=['c_' + str(col) for col in embedded_df.columns]
    embedded_df['clean_text'] = text
    embedded_df['text']=data.iloc[i:end_i]['text'].values
    embedded_df['label']=data.iloc[i:end_i]['label'].values
    encoded_text_df_list.append(embedded_df)
    r=1200000-(n%1000000)
    if ((i!=0) and (i%1000000==0)) or (i+batch_size>max_i):
        pd.concat(encoded_text_df_list, ignore_index=True).to_csv(path+'embeddings/mpnet_embed_df_part'+str(i)+'.csv', index=False)
        #pd.concat(encoded_text_df_list, ignore_index=True).to_parquet('embeddings/mpnet_embed_pq.gzip', compression='gzip')
        print('the first part of data is done and saved')

# %%
embedded_df.shape
# Out:
# (50000, 387)

# %% [markdown]
# ## Data Partitioning

# %% [markdown]
# we use Stratified random partitioning as we are dealing with imbalanced dataset. This is a valuable technique for dividing a dataset into training, validation, and test sets while ensuring that each subset maintains the same class distribution as the original dataset. This approach is particularly beneficial when working with imbalanced datasets, where certain classes are less represented than others. By stratifying the partitions based on the target variable's classes, we can create subsets that accurately reflect the overall dataset's class proportions. This strategy helps in training models that generalize well across different classes and avoid biases towards the majority class.

# %%
embd_data=pd.read_csv('embeddings/mpnet_embed_df.csv')

# %%
X = embd_data.drop('label', axis=1)
y = embd_data['label']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42, stratify=y)
train = pd.concat([X_train, y_train], axis=1)
test = pd.concat([X_test, y_test], axis=1)

# %% [markdown]
# I have done data partitioning as part of the modeling notebook. therefore, I have not saved the partitioned data from here.
